# %%
import pandas as pd
import numpy as np

# %%
import json
import codecs

def load_json(file_name):
    with open(file_name, "r", encoding='utf8') as file:
        data = json.load(file)
    return data

# %%
data1 = load_json("data/comments_topic1.json")
data2 = load_json("data/comments_topic2.json")
data3 = load_json("data/comments_topic3.json")
data4 = load_json("data/comments_topic4.json")

data_list = [data1, data2, data3, data4]

for i in range(len(data_list)):
    print(f"the size of the data{i}:", len(data_list[i]))
# Out:
# the size of the data0: 124
# the size of the data1: 20
# the size of the data2: 36
# the size of the data3: 22

# %%
topic1 = "Miten läheisen kuolemaan liittyvästä asioinnista voisi tehdä helpompaa?"
topic2 = "Mitä mieltä Suomi?"
topic3 = "Mitä mieltä olet Siun soten palveluista?"
topic4 = "Maaseutupoliittisen selonteon Polis-alusta"

# %% [markdown]
# ## Translating the text

# %%
from googletrans import Translator

def translate(str):
    translator = Translator()
    trans_text = translator.translate(str, lang_tgt='en')
    return trans_text.text

# %%
topics = [topic1, topic2, topic3, topic4]

translated_topics = [translate(topic) for topic in topics]
translated_topics
# Out:
# ['How could dealings related to the death of a loved one be made easier?',
#  'What does Finland think?',
#  "What do you think of Siu sote's services?",
#  'The Polis platform for rural political reporting']

# %%
dfs = []
i = 1
for data, topic, topic_en in zip(data_list, topics, translated_topics):
    df = pd.DataFrame(data)
    df['topic'] = topic
    df['topic_en'] = topic_en
    dfs.append(df)
    i +=1

# %%
df = pd.concat(dfs, ignore_index=True)
df['is_seed'] = df['is_seed'].astype(int)
df['is_meta'] = df['is_meta'].astype(int)
df
# Out:
#                                                    txt  tid        created  \
# 0                 Taustaväittämä: Olen yli 70-vuotias.    0  1730459323436
# 1    Taustaväittämä: Asun lähellä monipuolisia palv...    1  1730459326181
# 2    Taustaväittämä: Olen taitava käyttämään digita...    2  1730459334376
# 3    Taustaväittämä: Minulla on paljon kokemusta ed...    3  1730459344879
# 4    Julkisella puolella on ei ole rahaa tarjota si...    4  1730459375795
# ..                                                 ...  ...            ...
# 197  Ilmastopakolaisuuteen ei ole varauduttu riittä...   20  1730987957543
# 198  Maaseudulla on liian hankala saada pankilta ra...   21  1731049686447
# 199  Maaseudun yritykset luovat maaseudun tulevaisu...   22  1731049708635
# 200  Alueellani on hyvät edellytykset matkailualan ...   23  1731067305877
# 201  Tiestö on suomalaisella maaseudulla hyvässä ku...   24  1731067341437
#
#     tweet_id quote_src_url  is_seed  is_meta lang  pid  velocity  mod active  \
# 0       None          None        1        1   fi    0       1.0  1.0   True
# 1       None          None        1        1   fi    0       1.0  1.0   True
# 2       None          None        1        1   fi    0       1.0  1.0   True
# 3       None          None        1        1   fi    0       1.0  1.0   True
# 4       None          None        1        0   fi    0       1.0  1.0   True
# ..       ...           ...      ...      ...  ...  ...       ...  ...    ...
# 197     None          None        0        0   fi    4       NaN  NaN    NaN
# 198     None          None        1        0   fi    0       NaN  NaN    NaN
# 199     None          None        1        0   fi    0       NaN  NaN    NaN
# 200     None          None        1        0   fi    0       NaN  NaN    NaN
# 201     None          None        1        0   fi    0       NaN  NaN    NaN
#
#      agree_count  disagree_count  pass_count  count conversation_id  \
# 0           26.0           329.0        21.0  376.0      8sr6bhp8kr
# 1          266.0            64.0        47.0  377.0      8sr6bhp8kr
# 2          306.0            24.0        53.0  383.0      8sr6bhp8kr
# 3          205.0           115.0        50.0  370.0      8sr6bhp8kr
# 4          110.0            18.0       157.0  285.0      8sr6bhp8kr
# ..           ...             ...         ...    ...             ...
# 197          NaN             NaN         NaN    NaN             NaN
# 198          NaN             NaN         NaN    NaN             NaN
# 199          NaN             NaN         NaN    NaN             NaN
# 200          NaN             NaN         NaN    NaN             NaN
# 201          NaN             NaN         NaN    NaN             NaN
#
#                                                  topic  \
# 0    Miten läheisen kuolemaan liittyvästä asioinnis...
# 1    Miten läheisen kuolemaan liittyvästä asioinnis...
# 2    Miten läheisen kuolemaan liittyvästä asioinnis...
# 3    Miten läheisen kuolemaan liittyvästä asioinnis...
# 4    Miten läheisen kuolemaan liittyvästä asioinnis...
# ..                                                 ...
# 197         Maaseutupoliittisen selonteon Polis-alusta
# 198         Maaseutupoliittisen selonteon Polis-alusta
# 199         Maaseutupoliittisen selonteon Polis-alusta
# 200         Maaseutupoliittisen selonteon Polis-alusta
# 201         Maaseutupoliittisen selonteon Polis-alusta
#
#                                               topic_en
# 0    How could dealings related to the death of a l...
# 1    How could dealings related to the death of a l...
# 2    How could dealings related to the death of a l...
# 3    How could dealings related to the death of a l...
# 4    How could dealings related to the death of a l...
# ..                                                 ...
# 197   The Polis platform for rural political reporting
# 198   The Polis platform for rural political reporting
# 199   The Polis platform for rural political reporting
# 200   The Polis platform for rural political reporting
# 201   The Polis platform for rural political reporting
#
# [202 rows x 19 columns]

# %%
# removing the "Taustaväittämä:"
df = df[~df['txt'].str.contains('Taustaväittämä:')]
# df['txt'].str.contains('Taustaväittämä').value_counts()
df.reset_index(drop=True)
# Out:
#                                                    txt  tid        created  \
# 0    Julkisella puolella on ei ole rahaa tarjota si...    4  1730459375795
# 1    Luotan siihen, että minusta ja edesmenneestä l...    5  1730459390574
# 2    Jos kaikki palvelut kootaan yhteen kokonaisuut...    6  1730459397488
# 3    Jos voin asioida omaiseni puolesta helpommin, ...    7  1730459403425
# 4      Kun läheiseni kuoli, koin asioinnin hankalaksi.    8  1730459411906
# ..                                                 ...  ...            ...
# 193  Ilmastopakolaisuuteen ei ole varauduttu riittä...   20  1730987957543
# 194  Maaseudulla on liian hankala saada pankilta ra...   21  1731049686447
# 195  Maaseudun yritykset luovat maaseudun tulevaisu...   22  1731049708635
# 196  Alueellani on hyvät edellytykset matkailualan ...   23  1731067305877
# 197  Tiestö on suomalaisella maaseudulla hyvässä ku...   24  1731067341437
#
#     tweet_id quote_src_url  is_seed  is_meta lang  pid  velocity  mod active  \
# 0       None          None        1        0   fi    0       1.0  1.0   True
# 1       None          None        1        0   fi    0       1.0  1.0   True
# 2       None          None        1        0   fi    0       1.0  1.0   True
# 3       None          None        1        0   fi    0       1.0  1.0   True
# 4       None          None        1        0   fi    0       1.0  1.0   True
# ..       ...           ...      ...      ...  ...  ...       ...  ...    ...
# 193     None          None        0        0   fi    4       NaN  NaN    NaN
# 194     None          None        1        0   fi    0       NaN  NaN    NaN
# 195     None          None        1        0   fi    0       NaN  NaN    NaN
# 196     None          None        1        0   fi    0       NaN  NaN    NaN
# 197     None          None        1        0   fi    0       NaN  NaN    NaN
#
#      agree_count  disagree_count  pass_count  count conversation_id  \
# 0          110.0            18.0       157.0  285.0      8sr6bhp8kr
# 1          162.0            52.0        77.0  291.0      8sr6bhp8kr
# 2          238.0            16.0        43.0  297.0      8sr6bhp8kr
# 3          138.0            77.0        88.0  303.0      8sr6bhp8kr
# 4          199.0            27.0        78.0  304.0      8sr6bhp8kr
# ..           ...             ...         ...    ...             ...
# 193          NaN             NaN         NaN    NaN             NaN
# 194          NaN             NaN         NaN    NaN             NaN
# 195          NaN             NaN         NaN    NaN             NaN
# 196          NaN             NaN         NaN    NaN             NaN
# 197          NaN             NaN         NaN    NaN             NaN
#
#                                                  topic  \
# 0    Miten läheisen kuolemaan liittyvästä asioinnis...
# 1    Miten läheisen kuolemaan liittyvästä asioinnis...
# 2    Miten läheisen kuolemaan liittyvästä asioinnis...
# 3    Miten läheisen kuolemaan liittyvästä asioinnis...
# 4    Miten läheisen kuolemaan liittyvästä asioinnis...
# ..                                                 ...
# 193         Maaseutupoliittisen selonteon Polis-alusta
# 194         Maaseutupoliittisen selonteon Polis-alusta
# 195         Maaseutupoliittisen selonteon Polis-alusta
# 196         Maaseutupoliittisen selonteon Polis-alusta
# 197         Maaseutupoliittisen selonteon Polis-alusta
#
#                                               topic_en
# 0    How could dealings related to the death of a l...
# 1    How could dealings related to the death of a l...
# 2    How could dealings related to the death of a l...
# 3    How could dealings related to the death of a l...
# 4    How could dealings related to the death of a l...
# ..                                                 ...
# 193   The Polis platform for rural political reporting
# 194   The Polis platform for rural political reporting
# 195   The Polis platform for rural political reporting
# 196   The Polis platform for rural political reporting
# 197   The Polis platform for rural political reporting
#
# [198 rows x 19 columns]

# %% [markdown]
# ## Translating the text

# %%
from googletrans import Translator

def translate(str):
    translator = Translator()
    trans_text = translator.translate(str, lang_tgt='en')
    return trans_text.text

# %%
topic1_en = translate(topic1)
print(topic1_en)
topic2_en = translate(topic2)
print(topic2_en)
# Out:
# How could dealings related to the death of a loved one be made easier?
# What does Finland think?

# %%
df.columns
# Out:
# Index(['txt', 'tid', 'created', 'tweet_id', 'quote_src_url', 'is_seed',
#        'is_meta', 'lang', 'pid', 'velocity', 'mod', 'active', 'agree_count',
#        'disagree_count', 'pass_count', 'count', 'conversation_id', 'topic',
#        'topic_en'],
#       dtype='object')

# %%
df['lang'].value_counts()
# all the comments are in finnish
# Out:
# lang
# fi    198
# Name: count, dtype: int64

# %%
df['txt_en'] = df['txt'].apply(lambda x: translate(x))
df.drop(columns=['tid', 'created', 'tweet_id', 'quote_src_url', 'lang', 'pid', 'velocity', 'mod', 'active', 'conversation_id'], inplace=True)
df = df[['topic', 'topic_en', 'txt', 'txt_en', 'is_seed', 'is_meta', 'agree_count', 'disagree_count',
       'pass_count', 'count']]
df
# Out:
#                                                  topic  \
# 4    Miten läheisen kuolemaan liittyvästä asioinnis...
# 5    Miten läheisen kuolemaan liittyvästä asioinnis...
# 6    Miten läheisen kuolemaan liittyvästä asioinnis...
# 7    Miten läheisen kuolemaan liittyvästä asioinnis...
# 8    Miten läheisen kuolemaan liittyvästä asioinnis...
# ..                                                 ...
# 197         Maaseutupoliittisen selonteon Polis-alusta
# 198         Maaseutupoliittisen selonteon Polis-alusta
# 199         Maaseutupoliittisen selonteon Polis-alusta
# 200         Maaseutupoliittisen selonteon Polis-alusta
# 201         Maaseutupoliittisen selonteon Polis-alusta
#
#                                               topic_en  \
# 4    How could dealings related to the death of a l...
# 5    How could dealings related to the death of a l...
# 6    How could dealings related to the death of a l...
# 7    How could dealings related to the death of a l...
# 8    How could dealings related to the death of a l...
# ..                                                 ...
# 197   The Polis platform for rural political reporting
# 198   The Polis platform for rural political reporting
# 199   The Polis platform for rural political reporting
# 200   The Polis platform for rural political reporting
# 201   The Polis platform for rural political reporting
#
#                                                    txt  \
# 4    Julkisella puolella on ei ole rahaa tarjota si...
# 5    Luotan siihen, että minusta ja edesmenneestä l...
# 6    Jos kaikki palvelut kootaan yhteen kokonaisuut...
# 7    Jos voin asioida omaiseni puolesta helpommin, ...
# 8      Kun läheiseni kuoli, koin asioinnin hankalaksi.
# ..                                                 ...
# 197  Ilmastopakolaisuuteen ei ole varauduttu riittä...
# 198  Maaseudulla on liian hankala saada pankilta ra...
# 199  Maaseudun yritykset luovat maaseudun tulevaisu...
# 200  Alueellani on hyvät edellytykset matkailualan ...
# 201  Tiestö on suomalaisella maaseudulla hyvässä ku...
#
#                                                 txt_en  is_seed  is_meta  \
# 4    The public sector does not have the money to o...        1        0
# 5    I trust that the information collected about m...        1        0
# 6    If all services are combined into one entity, ...        1        0
# 7    If I can do business on behalf of my family mo...        1        0
# 8    When my loved one died, I found it difficult t...        1        0
# ..                                                 ...      ...      ...
# 197  There is not enough preparation for climate em...        0        0
# 198  In rural areas, it is too difficult to get fin...        1        0
# 199  Rural companies create the future of rural areas.        1        0
# 200  My area has good conditions for tourism compan...        1        0
# 201  Tiestö is in good condition in the Finnish cou...        1        0
#
#      agree_count  disagree_count  pass_count  count
# 4          110.0            18.0       157.0  285.0
# 5          162.0            52.0        77.0  291.0
# 6          238.0            16.0        43.0  297.0
# 7          138.0            77.0        88.0  303.0
# 8          199.0            27.0        78.0  304.0
# ..           ...             ...         ...    ...
# 197          NaN             NaN         NaN    NaN
# 198          NaN             NaN         NaN    NaN
# 199          NaN             NaN         NaN    NaN
# 200          NaN             NaN         NaN    NaN
# 201          NaN             NaN         NaN    NaN
#
# [198 rows x 10 columns]

# %%
df.to_csv('data/topics_google_four.csv')
