# %%
import pandas as pd
import numpy as np

# %%
import json
import codecs

def load_json(file_name):
    with open(file_name, "r", encoding='utf8') as file:
        data = json.load(file)
    return data

# %%
data1 = load_json("data/comments_topic1.json")
data2 = load_json("data/comments_topic2.json")
print("the size of the data1:", len(data1))
print("the size of the data2:", len(data2))
# Out:
# the size of the data1: 124
# the size of the data2: 20

# %%
topic1 = "Miten läheisen kuolemaan liittyvästä asioinnista voisi tehdä helpompaa?"
topic2 = "Mitä mieltä Suomi?"

# %% [markdown]
# ## Translating the text

# %%
from googletrans import Translator

def translate(str):
    translator = Translator()
    trans_text = translator.translate(str, lang_tgt='en')
    return trans_text.text

# %%
topic1_en = translate(topic1)
print(topic1_en)
topic2_en = translate(topic2)
print(topic2_en)
# Out:
# How could dealings related to the death of a loved one be made easier?
# What does Finland think?

# %%
df1 = pd.DataFrame(data1)
df1['topic'] = topic1
df1['topic_en'] = topic1_en
df2 = pd.DataFrame(data2)
df2['topic'] = topic2
df2['topic_en'] = topic2_en

# %%
df = pd.concat([df1, df2], ignore_index=True)
df['is_seed'] = df['is_seed'].astype(int)
df['is_meta'] = df['is_meta'].astype(int)
df.head()
# Out:
#                                                  txt  tid        created  \
# 0               Taustaväittämä: Olen yli 70-vuotias.    0  1730459323436
# 1  Taustaväittämä: Asun lähellä monipuolisia palv...    1  1730459326181
# 2  Taustaväittämä: Olen taitava käyttämään digita...    2  1730459334376
# 3  Taustaväittämä: Minulla on paljon kokemusta ed...    3  1730459344879
# 4  Julkisella puolella on ei ole rahaa tarjota si...    4  1730459375795
#
#   tweet_id quote_src_url  is_seed  is_meta lang  pid  velocity  mod  active  \
# 0     None          None        1        1   fi    0         1    1    True
# 1     None          None        1        1   fi    0         1    1    True
# 2     None          None        1        1   fi    0         1    1    True
# 3     None          None        1        1   fi    0         1    1    True
# 4     None          None        1        0   fi    0         1    1    True
#
#    agree_count  disagree_count  pass_count  count conversation_id  \
# 0           26             329          21    376      8sr6bhp8kr
# 1          266              64          47    377      8sr6bhp8kr
# 2          306              24          53    383      8sr6bhp8kr
# 3          205             115          50    370      8sr6bhp8kr
# 4          110              18         157    285      8sr6bhp8kr
#
#                                                topic  \
# 0  Miten läheisen kuolemaan liittyvästä asioinnis...
# 1  Miten läheisen kuolemaan liittyvästä asioinnis...
# 2  Miten läheisen kuolemaan liittyvästä asioinnis...
# 3  Miten läheisen kuolemaan liittyvästä asioinnis...
# 4  Miten läheisen kuolemaan liittyvästä asioinnis...
#
#                                             topic_en
# 0  How could dealings related to the death of a l...
# 1  How could dealings related to the death of a l...
# 2  How could dealings related to the death of a l...
# 3  How could dealings related to the death of a l...
# 4  How could dealings related to the death of a l...

# %%
# removing the "Taustaväittämä:"
df['txt'] = df['txt'].str.replace('Taustaväittämä:', '', regex=False)
df
# Out:
#                                                    txt  tid        created  \
# 0                                 Olen yli 70-vuotias.    0  1730459323436
# 1                 Asun lähellä monipuolisia palveluja.    1  1730459326181
# 2     Olen taitava käyttämään digitaalisia palveluita.    2  1730459334376
# 3     Minulla on paljon kokemusta edesmenneen omais...    3  1730459344879
# 4    Julkisella puolella on ei ole rahaa tarjota si...    4  1730459375795
# ..                                                 ...  ...            ...
# 139  Ylikulutukseen perustuvaa talousjärjestelmäämm...   16  1731105967831
# 140  Ruotsin jengirikollisuus tulee myös Suomeen mu...   17  1731105967831
# 141  Valtion pitää panostaa taloudellisesti nuorten...   18  1731105967831
# 142  Kännyköiden käytöstä on päätettävä kouluissa, ...   19  1731105967831
# 143  Kännykät tulisi kieltää kouluissa lasten hyvin...   20  1731105967831
#
#     tweet_id quote_src_url  is_seed  is_meta lang  pid  velocity  mod  active  \
# 0       None          None        1        1   fi    0         1    1    True
# 1       None          None        1        1   fi    0         1    1    True
# 2       None          None        1        1   fi    0         1    1    True
# 3       None          None        1        1   fi    0         1    1    True
# 4       None          None        1        0   fi    0         1    1    True
# ..       ...           ...      ...      ...  ...  ...       ...  ...     ...
# 139     None          None        1        0   fi    0         5    5    True
# 140     None          None        1        0   fi    0         3    5    True
# 141     None          None        1        0   fi    0         2    4    True
# 142     None          None        0        0   fi    0         1    3    True
# 143     None          None        1        0   fi    0         3    5    True
#
#      agree_count  disagree_count  pass_count  count conversation_id  \
# 0             26             329          21    376      8sr6bhp8kr
# 1            266              64          47    377      8sr6bhp8kr
# 2            306              24          53    383      8sr6bhp8kr
# 3            205             115          50    370      8sr6bhp8kr
# 4            110              18         157    285      8sr6bhp8kr
# ..           ...             ...         ...    ...             ...
# 139          153              42         195    390      8sr6bhp8kr
# 140          181              27         147    355      8sr6bhp8kr
# 141          147              25         154    326      8sr6bhp8kr
# 142           51              13         155    219      8sr6bhp8kr
# 143           75              33          52    160      8sr6bhp8kr
#
#                                                  topic  \
# 0    Miten läheisen kuolemaan liittyvästä asioinnis...
# 1    Miten läheisen kuolemaan liittyvästä asioinnis...
# 2    Miten läheisen kuolemaan liittyvästä asioinnis...
# 3    Miten läheisen kuolemaan liittyvästä asioinnis...
# 4    Miten läheisen kuolemaan liittyvästä asioinnis...
# ..                                                 ...
# 139                                 Mitä mieltä Suomi?
# 140                                 Mitä mieltä Suomi?
# 141                                 Mitä mieltä Suomi?
# 142                                 Mitä mieltä Suomi?
# 143                                 Mitä mieltä Suomi?
#
#                                               topic_en
# 0    How could dealings related to the death of a l...
# 1    How could dealings related to the death of a l...
# 2    How could dealings related to the death of a l...
# 3    How could dealings related to the death of a l...
# 4    How could dealings related to the death of a l...
# ..                                                 ...
# 139                           What does Finland think?
# 140                           What does Finland think?
# 141                           What does Finland think?
# 142                           What does Finland think?
# 143                           What does Finland think?
#
# [144 rows x 19 columns]

# %%
df.columns
# Out:
# Index(['txt', 'tid', 'created', 'tweet_id', 'quote_src_url', 'is_seed',
#        'is_meta', 'lang', 'pid', 'velocity', 'mod', 'active', 'agree_count',
#        'disagree_count', 'pass_count', 'count', 'conversation_id', 'topic',
#        'topic_en'],
#       dtype='object')

# %%
df['lang'].value_counts()
# all the comments are in finnish
# Out:
# lang
# fi    144
# Name: count, dtype: int64

# %%
df['txt_en'] = df['txt'].apply(lambda x: translate(x))
df.drop(columns=['tid', 'created', 'tweet_id', 'quote_src_url', 'lang', 'pid', 'velocity', 'mod', 'active', 'conversation_id'], inplace=True)

# %%
# pd.set_option('display.width', None)
# pd.set_option('display.max_rows', None)
# pd.set_option('display.max_columns', None)

pd.reset_option('display.max_rows')

# %%
df = df[['topic', 'topic_en', 'txt', 'txt_en', 'is_seed', 'is_meta', 'agree_count', 'disagree_count',
       'pass_count', 'count']]
df.to_csv('data/topics_google_two.csv')
